# %% [markdown]
# ## Seaborn Assignment

# %%
# import pandas
import pandas as pd

# import seaborn
import seaborn as sns

# import matplotlib
import matplotlib.pyplot as plt

import numpy as np

# %%
df = pd.read_csv('/Users/kitanolowofoyeku/Downloads/pokemon.csv',sep=',')
df.drop('#',axis=1,inplace=True)

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Task 1: Plot a regression line between attack and defense.

# %%
sns.lmplot(data=df, x="Attack", y="Defense")

# %% [markdown]
# ### Task 2: Plot a regression line between attack and defense while displaying a distinction between the different generations.

# %%
sns.lmplot(data=df, x="Attack", y="Defense", hue='Generation')

# %%
sns.lmplot(data=df, x="Attack", y="Defense", col='Generation')

# %% [markdown]
# ### Task 3: Make a boxplot for each feature of dataframe (without Generation and Legendary features) in one plot.

# %%
ax = sns.boxplot(data=df3, orient="h", palette="Set2")
ax.drop(df['Generation'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [31], in <cell line: 2>()
#       1 ax = sns.boxplot(data=df3, orient="h", palette="Set2")
# ----> 2 ax.drop(df['Generation'])
#
# AttributeError: 'AxesSubplot' object has no attribute 'drop'

# %% [markdown]
# ### Task 4: Plot a correlation heatmap of the pokemon dataframe (not including the features Generation and Legendary).

# %%
plt.figure(figsize=(16, 6))
mask = np.triu(np.ones_like(df4.corr(), dtype=np.bool))
heatmap = sns.heatmap(df4.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Triangle Correlation Heatmap', fontdict={'fontsize':18}, pad=16);
# Out:
# /var/folders/nf/j2sd7_ns0cx3qfryzvfmplp00000gn/T/ipykernel_1450/2590425739.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df4.corr(), dtype=np.bool))

# %%
df4 = df3
del df['Name']
del df['Type 1']
del df['Type 2']

# %%
df4
# Out:
#      Total  HP  Defense  Sp. Atk  Sp. Def  Speed
# 0      318  45       49       65       65     45
# 1      405  60       63       80       80     60
# 2      525  80       83      100      100     80
# 3      625  80      123      122      120     80
# 4      309  39       43       60       50     65
# ..     ...  ..      ...      ...      ...    ...
# 795    600  50      150      100      150     50
# 796    700  50      110      160      110    110
# 797    600  80       60      150      130     70
# 798    680  80       60      170      130     80
# 799    600  80      120      130       90     70
#
# [800 rows x 6 columns]
